# %%
#Importing required dependencies

import tweepy
import pymongo
import json
import time

print("Dependencies imported")
# Out:
# Dependencies imported

# %%
#TO DO: Add to config file later

consumer_key = "mQXkO4dzpD3OPD1nOIT3fuD0j"
consumer_secret = "obt5r2qT1o878i5Eja7GYropJfCeUX76IXcjXRuHoJjIZnaard"
users_database_name = "users_test"
user_followers_database = "user_followers_test"
tweets_database = "user_tweets_test"

seed_usernames = ["P9Ashwini", 
                  "drashwathcn", 
                  "Tej_AnanthKumar", 
                  "vijeta_at", 
                  "nimmasuresh", 
                  "ShashikalaJolle"]

# %%
#Storing in MongoDB database

client = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = client["mydatabase_test"]
user_col = mydb[users_database_name]
user_follower_col = mydb[user_followers_database]
tweets_col = mydb[tweets_database]

# %%
#Checking for collections in DB

collist = mydb.list_collection_names()
print(collist)
if users_database_name in collist:
    print("Users collection exists")

else:
    print("ERR: Users collection doesn't exist yet")
# Out:
# ['user_tweets_test', 'users_test']
# Users collection exists

# %%
#OAuth2 Authentication

def get_authenticated_twitter_api():
    auth = tweepy.AppAuthHandler(consumer_key, consumer_secret)
    api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
    return api

# %%
#Save the users info and recent tweets in local DB

def save_user(user_dict):
    try:
        user_info = {"_id":user_dict["id_str"],
                     "name":user_dict["name"], 
                     "screen_name":user_dict["screen_name"], 
                     "followers":user_dict["followers_count"], 
                     "friends":user_dict["friends_count"]}

        x = user_col.insert_one(user_info)

        #Fetching tweets of the user
        api = get_authenticated_twitter_api()
        tweets = api.user_timeline(user_dict["id"])
        for tweet_obj in tweets:
            tweet = tweet_obj._json
            tweet_info = {"_id":tweet["id_str"],
                          "user_id":user_dict["id_str"],
                          "follower_count":user_dict["followers_count"],
                          "retweet_count":tweet["retweet_count"]}

            y = tweets_col.insert_one(tweet_info)
            
        print("User info saved for", user_dict["id"])
            
    except Exception as ex:
        print(ex)

# %%
#Performing BFS on twitter users

def scrape_users(user_list):
    count = 0
    api = get_authenticated_twitter_api()
    try:
        while len(user_list)!=0:
            try:
                time.sleep(10)
                if count%100==0:
                    if(count!=0):
                        print("Pausing...")


                while(1):
                    user_id = user_list.pop(0)

                    #Checking if user node not already visited
                    query = {"_id": user_id }
                    query_res = user_col.find(query)

                    qcount = 0
                    for query in query_res:
                        qcount = 1

                    if (qcount)==0:
                        break

                followers = []
                for follower in tweepy.Cursor(api.followers, id=user_id).items():
                    if "bangalore" in follower._json["location"].lower() or "bengaluru" in follower._json["location"].lower():
                        user_list.append(follower._json["id_str"])
                        followers.append(follower._json["id_str"])
                        save_user(follower._json)
                        count = count+1

                #Saving followers of a user        
                follower_info = {"_id":user_id, 
                                 "followers": followers }

                try:
                    user_follower_col.insert_one(follower_info)

                except:
                    print("User's followers already stored")

                if count>5000:
                    break
                    
            except Exception as ex:
                print(ex, " occured inside loop")
                 time.sleep(200)
                
    except Exception as ex:
        print(ex, " occured outside loop")

# %%
#Fetching user ids of popular seed users

def initialise(seed_usernames):
    seed_users = []
    api = get_authenticated_twitter_api()
    for seed in seed_usernames:
        res = api.get_user(seed)
        #print(res)
        seed_users.append(res._json["id_str"])
        
    print(seed_users)
    return seed_users

# %%
#Fetching seed ids

seed_users = initialise(seed_usernames)
# Out:
# ['1213502011', '2885971046', '1067115424339435520', '2307766760', '43705720', '704994405065760768']

# %%
#Drop the existing collections

user_col.drop()
user_follower_col.drop()
tweets_col.drop()

# %%
seed_users = ['1213502011', '2885971046', '1067115424339435520', '2307766760', '43705720', '704994405065760768']

scrape_users(seed_users)
# Out:
# User info saved for 66338610
# User info saved for 849157018833342464
# User info saved for 3275260856
# User info saved for 364720514
# User info saved for 1218462519104159745
# User info saved for 139092034
# User info saved for 624649724
# User info saved for 51379431
# User info saved for 1216368239527133186
# User info saved for 393845265
# User info saved for 1217712610461638656
# User info saved for 1124704857552592896
# User info saved for 146913591
# User info saved for 1041641552760647681
# User info saved for 604375461
# User info saved for 2546737348
# Not authorized.
# User info saved for 1208802953181585408
# Rate limit reached. Sleeping for: 756
# Failed to send request: ('Connection aborted.', OSError("(104, 'ECONNRESET')"))

# %%
for x in tweets_col.find():
    print(x)
# Out:
# {'_id': '1234117137922289665', 'user_id': '66338610', 'follower_count': 16, 'retweet_count': 0}
# {'_id': '1221877238401912832', 'user_id': '66338610', 'follower_count': 16, 'retweet_count': 0}
# {'_id': '1220744349526319104', 'user_id': '66338610', 'follower_count': 16, 'retweet_count': 0}
# {'_id': '1220272754315821056', 'user_id': '66338610', 'follower_count': 16, 'retweet_count': 0}
# {'_id': '1211658418936631296', 'user_id': '66338610', 'follower_count': 16, 'retweet_count': 0}
# {'_id': '1161642946732494848', 'user_id': '66338610', 'follower_count': 16, 'retweet_count': 0}
# {'_id': '1234472361421758469', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 0}
# {'_id': '1232938314312773633', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 0}
# {'_id': '1232568152938008576', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 0}
# {'_id': '1232567715962839040', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 0}
# {'_id': '1232567286076039168', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 0}
# {'_id': '1232566901328363522', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 0}
# {'_id': '1232566578891255808', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 0}
# {'_id': '1232561560909803520', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 0}
# {'_id': '1232279207687811072', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 0}
# {'_id': '1204833527641980928', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 0}
# {'_id': '1201472434928357376', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 0}
# {'_id': '1110211843044327424', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 0}
# {'_id': '1110211155488899072', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 0}
# {'_id': '1102918659037716480', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 0}
# {'_id': '1097869174158823425', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 1}
# {'_id': '1097855324780924928', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 1}
# {'_id': '1097747865001181185', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 2}
# {'_id': '1097685706703556610', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 1}
# {'_id': '1097492938203062273', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 1}
# {'_id': '1097438085191778305', 'user_id': '849157018833342464', 'follower_count': 52, 'retweet_count': 1}
# {'_id': '1232140795471261697', 'user_id': '3275260856', 'follower_count': 11, 'retweet_count': 0}
# {'_id': '1231940013350359040', 'user_id': '3275260856', 'follower_count': 11, 'retweet_count': 0}
# {'_id': '1227076602833465344', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 0}
# {'_id': '1221689276124950528', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 1}
# {'_id': '1217787844321636353', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 5}
# {'_id': '1186665194358857729', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 0}
# {'_id': '928916748455178240', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 5}
# {'_id': '928916706595979265', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 5}
# {'_id': '913990765000265728', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 0}
# {'_id': '859672955143507969', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 8}
# {'_id': '857138879828295681', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 2}
# {'_id': '856798198307926017', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 0}
# {'_id': '855280862547525632', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 0}
# {'_id': '854602080362868737', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 0}
# {'_id': '854592559125073920', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 0}
# {'_id': '854582194723008512', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 0}
# {'_id': '853891232489242624', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 82}
# {'_id': '852748122081984512', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 11}
# {'_id': '852345815108653056', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 9}
# {'_id': '851755168014241797', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 10}
# {'_id': '849958530845200385', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 9}
# {'_id': '849628380152680448', 'user_id': '364720514', 'follower_count': 242, 'retweet_count': 0}
# {'_id': '1234460178713473024', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1234455847062736896', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 4}
# {'_id': '1234144951673466880', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1234141829114757136', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 1}
# {'_id': '1234123111684923393', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 1}
# {'_id': '1234054744697524224', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1233669575092293633', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1233663421469478912', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1232495071741693954', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 9054}
# {'_id': '1232220444347883520', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 28223}
# {'_id': '1231905315135709184', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1231903496464556033', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1231893869442326528', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 11}
# {'_id': '1231852486165549057', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 5825}
# {'_id': '1231810989793759232', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 28983}
# {'_id': '1231450073793363969', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 124}
# {'_id': '1231085016571990017', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 758}
# {'_id': '1231066120087429127', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1230739922618740738', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1230687594045956096', 'user_id': '1218462519104159745', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1234697120344526848', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1231978004953174016', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1229999030517686273', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1228505486435082240', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1226708621334958081', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1225232840108826624', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1224355139294613504', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1222390987768483841', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1221777214946938882', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1221457843854774274', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1220709355865034752', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1218208649379635202', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1215284388159602689', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1214217229723557888', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1210162115706679296', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1209125865914650625', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1207635725711134722', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1202878076910100481', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 1}
# {'_id': '1199706400395390977', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1197341079655174145', 'user_id': '139092034', 'follower_count': 276, 'retweet_count': 0}
# {'_id': '1233410509078056960', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 0}
# {'_id': '1233030293226954753', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 0}
# {'_id': '1231822113213804544', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 0}
# {'_id': '1229784110580871171', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 0}
# {'_id': '1226087915383480320', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 0}
# {'_id': '1223635019723206656', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 0}
# {'_id': '1223091046680186882', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 0}
# {'_id': '1222908004997009409', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 0}
# {'_id': '1222319397219360768', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 0}
# {'_id': '1222204250748416000', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 0}
# {'_id': '1221966067653722113', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 0}
# {'_id': '1221963635179679744', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 0}
# {'_id': '1220575638454583297', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 0}
# {'_id': '1220385477544439808', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 2}
# {'_id': '1219271628107870208', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 1070}
# {'_id': '1218202841271062529', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 6}
# {'_id': '1217436148802318338', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 0}
# {'_id': '1217033630045728778', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 340}
# {'_id': '1217028447530151937', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 80}
# {'_id': '1217020483624816640', 'user_id': '624649724', 'follower_count': 28, 'retweet_count': 49}
# {'_id': '1230494703600062464', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 0}
# {'_id': '1189393142329626624', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 0}
# {'_id': '1185203031534530562', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 0}
# {'_id': '1177482995051024386', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 35}
# {'_id': '1166646916462993408', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 5}
# {'_id': '1135008422133239808', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 0}
# {'_id': '1135003815961194496', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 0}
# {'_id': '1134992003966443520', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 0}
# {'_id': '1134982757287964674', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 0}
# {'_id': '1124128931458703362', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 7}
# {'_id': '1121701199625867265', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 0}
# {'_id': '1121694372855046144', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 0}
# {'_id': '1121693707005116416', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 0}
# {'_id': '1121693647810879488', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 0}
# {'_id': '1114488346506448896', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 0}
# {'_id': '1111262489549946882', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 0}
# {'_id': '1111257624731942912', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 0}
# {'_id': '1111251294272970752', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 0}
# {'_id': '1107272407453069312', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 4}
# {'_id': '1098188236256534530', 'user_id': '51379431', 'follower_count': 41, 'retweet_count': 1}
# {'_id': '1234144738070102016', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 1096}
# {'_id': '1234143447403110402', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1234143174307786753', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1232309398883581953', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1232033099309109248', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1230560675480535041', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1230402258820456448', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1230402251648159745', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1229842905793064960', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 1}
# {'_id': '1229842623042449408', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1228299120772702208', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1228292161398984704', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1228209143573442561', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1228123386225651712', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1223614540203479041', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1222335798994862080', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1222054483732992000', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1221260564535500800', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1220972354785828865', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1220971328439607296', 'user_id': '1216368239527133186', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '743402189050224641', 'user_id': '393845265', 'follower_count': 3, 'retweet_count': 1312}
# {'_id': '742798566414909440', 'user_id': '393845265', 'follower_count': 3, 'retweet_count': 146}
# {'_id': '1231256459452637184', 'user_id': '1217712610461638656', 'follower_count': 1, 'retweet_count': 2472}
# {'_id': '1230871047747989504', 'user_id': '1217712610461638656', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1229050292072636417', 'user_id': '1217712610461638656', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1229043034341330952', 'user_id': '1217712610461638656', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1205786121600266241', 'user_id': '1124704857552592896', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1125776777949802496', 'user_id': '1124704857552592896', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1124744741805912064', 'user_id': '1124704857552592896', 'follower_count': 1, 'retweet_count': 0}
# {'_id': '1234704489749155842', 'user_id': '146913591', 'follower_count': 18, 'retweet_count': 0}
# {'_id': '1234704025527783424', 'user_id': '146913591', 'follower_count': 18, 'retweet_count': 0}
# {'_id': '1228258004094472193', 'user_id': '146913591', 'follower_count': 18, 'retweet_count': 0}
# {'_id': '1228190369285693442', 'user_id': '146913591', 'follower_count': 18, 'retweet_count': 0}
# {'_id': '1228156721568206849', 'user_id': '146913591', 'follower_count': 18, 'retweet_count': 0}
# {'_id': '1219645323284340736', 'user_id': '146913591', 'follower_count': 18, 'retweet_count': 0}
# {'_id': '1219498011987869696', 'user_id': '146913591', 'follower_count': 18, 'retweet_count': 1801}
# {'_id': '1217125764719448064', 'user_id': '146913591', 'follower_count': 18, 'retweet_count': 0}
# {'_id': '1217123116289122304', 'user_id': '146913591', 'follower_count': 18, 'retweet_count': 0}
# {'_id': '1214369092951367680', 'user_id': '146913591', 'follower_count': 18, 'retweet_count': 0}
# {'_id': '1210981535005863936', 'user_id': '146913591', 'follower_count': 18, 'retweet_count': 0}
# {'_id': '1188852158000582662', 'user_id': '146913591', 'follower_count': 18, 'retweet_count': 1589}
# {'_id': '1188851979147071488', 'user_id': '146913591', 'follower_count': 18, 'retweet_count': 162}
# {'_id': '405666900417314816', 'user_id': '146913591', 'follower_count': 18, 'retweet_count': 0}
# {'_id': '378701120924708864', 'user_id': '146913591', 'follower_count': 18, 'retweet_count': 0}
# {'_id': '378700733144514560', 'user_id': '146913591', 'follower_count': 18, 'retweet_count': 0}
# {'_id': '1233764914797387777', 'user_id': '1041641552760647681', 'follower_count': 9, 'retweet_count': 20753}
# {'_id': '1229837977607532544', 'user_id': '1041641552760647681', 'follower_count': 9, 'retweet_count': 1131}
# {'_id': '1227172924731224065', 'user_id': '1041641552760647681', 'follower_count': 9, 'retweet_count': 87948}
# {'_id': '1068062156908912640', 'user_id': '1041641552760647681', 'follower_count': 9, 'retweet_count': 3526}
# {'_id': '1054755975410999296', 'user_id': '1041641552760647681', 'follower_count': 9, 'retweet_count': 1984}
# {'_id': '1049479409030316032', 'user_id': '1041641552760647681', 'follower_count': 9, 'retweet_count': 86}
# {'_id': '1043200809008283648', 'user_id': '1041641552760647681', 'follower_count': 9, 'retweet_count': 20224}
# {'_id': '1232970681475710976', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 0}
# {'_id': '1230515864882958338', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 405}
# {'_id': '1230395446339743744', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 0}
# {'_id': '1230391363025301504', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 0}
# {'_id': '1229443174747082760', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 0}
# {'_id': '1228040995461140480', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 0}
# {'_id': '1227417052983390208', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 0}
# {'_id': '1223803566508277762', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 167}
# {'_id': '1222558687530639360', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 0}
# {'_id': '1222450615940288512', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 0}
# {'_id': '1221838317060157443', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 0}
# {'_id': '1221472787832827904', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 0}
# {'_id': '1220261581361037312', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 356}
# {'_id': '1219138331092475904', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 71}
# {'_id': '1215723094121177089', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 0}
# {'_id': '1215713656735821824', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 39}
# {'_id': '1193220948259786752', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 0}
# {'_id': '1191944738196410376', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 281282}
# {'_id': '1189530250834657281', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 10685}
# {'_id': '1188387849801883648', 'user_id': '604375461', 'follower_count': 42, 'retweet_count': 0}
# {'_id': '1196659219665059840', 'user_id': '2546737348', 'follower_count': 12, 'retweet_count': 0}
# {'_id': '1195329462243483652', 'user_id': '2546737348', 'follower_count': 12, 'retweet_count': 0}
# {'_id': '1165648713231958016', 'user_id': '2546737348', 'follower_count': 12, 'retweet_count': 1}
# {'_id': '1232817434408542208', 'user_id': '1208802953181585408', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1228908540640686080', 'user_id': '1208802953181585408', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1228695320806088705', 'user_id': '1208802953181585408', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1217865696853413888', 'user_id': '1208802953181585408', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1217320192302149632', 'user_id': '1208802953181585408', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1217319452338839552', 'user_id': '1208802953181585408', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1217318519039086592', 'user_id': '1208802953181585408', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1217317428029349889', 'user_id': '1208802953181585408', 'follower_count': 0, 'retweet_count': 0}
# {'_id': '1209821793051004928', 'user_id': '1208802953181585408', 'follower_count': 0, 'retweet_count': 0}
